# %%
import pandas as pd
from langdetect import detect
from SPARQLWrapper import SPARQLWrapper, JSON
import re
import numpy as np
import sys
import os
import time
from nltk.tag import pos_tag
import urllib.parse

# %%
target = pd.read_csv("D:\Dokumenty\Zastosowanie Technologii Informatycznych\data\CEA_Round1_Targets.csv",
                    sep = ',',
                     skiprows=range(112,113), # 112 wadliwy wiersz
                    names=['TableID', 'ColumnID', 'RowID'])
target[:3]
# Out:
#                           TableID  ColumnID  RowID
# 0   50245608_0_871275842592178099         0    154
# 1  39107734_2_2329160387535788734         1     32
# 2  22864497_0_8632623712684511496         0    227

# %%
start = time.time()

# słownik, z którego będzie tworzony wynikowy df
answers_dict = {"TableID":[],
               "ColumnID":[],
               "RowID":[],
               "URI":[]}

# zmienna, aby ograniczyć liczbę przetwarzanych wierszy, niżej masz 3 linijki skomentowane,
# odkomentowujesz je i ustawiasz sobię liczbę wierszy w tym warunku, aktualnie 1000
counter = 0
# zlicza ile linków nie zostało znalezionych w ogóle,
# tzn. po wysłaniu zapytania nie dostaliśmy żądnej odpwiedzi od sparql (wiersze oznaczone przez NOT FOUND URI)
not_found_uris = 0

for index, row in target.iterrows():
    try:
#         counter = counter + 1
#         if counter == 100:
#             break


        table_id = row['TableID']
        column_id = row['ColumnID']
        row_id = row['RowID']
        
        # wczytanie odpowiedniej tabeli
        df = pd.read_csv(f"D:\Dokumenty\Zastosowanie Technologii Informatycznych\data\CEA_Round1\{table_id}.csv",
                    sep=',')
        
        # wyciągniecie wartości komórki, która nas interesuje
        cell_content = df.iloc[row_id-1:row_id, column_id:(column_id+1)].values[0][0]
        cell_content_copy = cell_content

        # usunięcie białych znaków z początku i końca stringa
        cell_content = cell_content.strip()
        

        # aktualnie nie używane, ale pewnie będzie
        # pos_tag() - kategoryzuje słowa, np. znajduje czasowniki, rzeczowniki, nazwy własne (jak imiona i nazwiska)
        # chodzi o to, że czasami odpowiedzi są w angielskiej dbpedii,
        # np. Alex Rodriguez wykrywa jako język ca - pewnie kataloński, 
        # ale nie ma jego odpowiednika w katalońskiej dbpedii, a w angielskiej jest
        # dlatego chcę wykrywać nazwy wkłasne jak imiona i nazwiska i wtedy zawsze szukać w angielksiej dbpedii,
        # ale z tym też był problem czasami i na razie nie myślałem nad tym dalej
        # NNP - to kategoria nazwy własnej, np. imię
#         tags = pos_tag(cell_content.split())
#         is_one_NNP = False
#         for tag in tags:
#             if tag[1] == "NNP":
#                 is_one_NNP = True
#                 break
#         try:
#             if is_one_NNP:
#                 lang = '@en'
#             else:
#                 lang = str('@') + str(detect(cell_content))
#         except Exception:
#             lang = ''

    
        # pierwsze zapytanie - bierze zawartość sformatowanej komórki i wyszukuje linku,
        # na razie jest ustawiona na stałe angielska dbpedia (#en) z powodu tego co wcześniej opisałem
        query = 'SELECT ?resource WHERE { { ?resource rdfs:label ' + '"' + str(cell_content) + '"' + "@en" + '}'
        
        
        cell_contents_list = []
        cell_contents_list.append(cell_content)
        cell_contents_list.append(cell_content.capitalize())
        # pojawiały się wartości typy "Guardian The", a powinno być "The Gurdian"
        if re.search(" The$", cell_content):
            index = cell_content.find(" The")
            cell_contents_list.append("The " + cell_content[:index].replace(',','').strip())
            cell_contents_list.append(cell_content[:index].strip())
       
    
        # zamienia wszystkie znaki odpowiadające kluczowi np. '[?]' na to co w wartości ''
        # każdy znak zamienia osobno. Nie wyszukuje stringa '[?]', tylko każdy znak po kolei szukam i zamieniam
        strings_to_replace_dict = [{'[?]':''}, {',':''}, {'-':' '}, {'?':''}] # dict = {chars_to_replace:new_char}
        for dicts in strings_to_replace_dict:
            for old_chars, new_char in dicts.items():
                cell_content_temp = cell_content
                for old_char in old_chars:
                    cell_content_temp = cell_content_temp.replace(old_char, new_char)
                if cell_content_temp not in cell_contents_list:
                    cell_contents_list.append(cell_content_temp)
        
        for cell_content in cell_contents_list:
            query = query + ' UNION { ?resource rdfs:label ' + '"' + str(cell_content) + '"' + "@en" + '} '
        
        lang = 'en'
        try:
            lang = detect(cell_content)
        except:
            pass
        
        if lang != 'en':
            for cell_content  in cell_contents_list:
                query = query + ' UNION { ?resource rdfs:label ' + '"' + str(cell_content) + '"' + '@' + str(lang) + '} '
        query = query + '}'
            
            
        sparql = SPARQLWrapper("http://dbpedia.org/sparql")
        sparql.setQuery(query)
        sparql.setReturnFormat(JSON)
        
        # jeśli wystąpi błąd z połączeniem się z serwerem to próbujemy aż do skutku
        results = None
        while results is None:
            try:
                results = sparql.query().convert()
            except Exception as e:
#                 print("EXCEPTION:" + str(e))
#                 print("TAKI: " + str(cell_content))
                continue
        

        # jeśli nic nie znaleziono no to trudno, nie mamy linku, wstawiamy NOT FOUND URI
        if str(results['results']['bindings']).find("http://dbpedia.org/resource/") == -1:
            answers_dict['TableID'].append(table_id)
            answers_dict['ColumnID'].append(column_id)
            answers_dict['RowID'].append(row_id)
            answers_dict['URI'].append("NOT FOUND URI")
            # printy przydatne do sprawdzania jakich zawartości nam nie wyszukał,
            # trzeba analizowac i dodawać kolejne warunki, zmieniać cell_content na różne sposoby
            print(table_id, column_id, row_id)
            print(cell_content_copy)
            print(query)
            not_found_uris = not_found_uris + 1
            continue

        # jeśli jednak mamy jakies linki to wyciągamy go z jsona,
        # linków może być więcej niż 1, aktualnie bierzemy pierwszy lepszy
        results_list = results['results']['bindings']
        for result_dict in results_list:
    #         print(result_dict)
            uri = result_dict['resource']['value']
            match = re.match("http://dbpedia.org/resource/*", uri)
            
            # czasami pojawiają dziwne linki np. http://dbpedia.org/resource/Category:Max_Weber
            # my takich nie chcemy i musimy ich unikać
            # interesują nas tylko np.  http://dbpedia.org/resource/Max_Weber
            # więc to jest warunek pozbywajacy się wszystkich linków z Category:
            if match and uri[5:].find("Category:") == -1:
                answers_dict['TableID'].append(table_id)
                answers_dict['ColumnID'].append(column_id)
                answers_dict['RowID'].append(row_id)
#                 answers_dict['URI'].append(str(uri)
#                 formatted_uri = 'http://dbpedia.org/resource/' + str(urllib.parse.quote(uri[28:]))
#                 formatted_uri = formatted_uri.replace('-','%E2%80%93')
                answers_dict['URI'].append(uri)
                break
    except Exception as e:
        # na początku były problemy z danymi, naprawiłem
        # potem zaczęły pojawiać sę problemy, żę serwer czasami nie odpowiadał,
        # więc jak jest error to olewamy i przechodzimy do następnego wiersza
        # będzie trzeba zrobić, że jak serwer nie odpowie z jakiegoś powodu to trzeba ponowić to samo zapytanie
        # zamiast pomijać, bo tracimy wiersze
        exc_type, exc_obj, exc_tb = sys.exc_info()
        print(table_id, column_id, row_id) # jaki plik, kolumna i wiersz
        print(cell_content_copy) # zawartość komórki
        print(e) # jaki błąd, teraz chyba tylko z brakiem połączenia z serwerem
        print(exc_tb.tb_lineno) # w jakiej liniii błąd
        continue



# print(answers_dict)
result_df = pd.DataFrame(answers_dict)
end = time.time()
print(end-start)
print(not_found_uris)
# Out:
# 13719111_1_5719401842463579519 0 48
# Ruppell's griffon vulture
# SELECT ?resource WHERE { { ?resource rdfs:label "Ruppell's griffon vulture"@en} UNION { ?resource rdfs:label "Ruppell's griffon vulture"@en}  UNION { ?resource rdfs:label "Ruppell's griffon vulture"@en}  UNION { ?resource rdfs:label "Ruppell's griffon vulture"@sv}  UNION { ?resource rdfs:label "Ruppell's griffon vulture"@sv} }
# 91959037_0_7907661684242014480 1 303
# Die Sims
# SELECT ?resource WHERE { { ?resource rdfs:label "Die Sims"@en} UNION { ?resource rdfs:label "Die Sims"@en}  UNION { ?resource rdfs:label "Die sims"@en}  UNION { ?resource rdfs:label "Die Sims"@af}  UNION { ?resource rdfs:label "Die sims"@af} }
# 75367212_2_2745466355267233390 0 16
# Legend of Zelda: Majora's MaskThe Legend of Zelda: Majora's Mask
# SELECT ?resource WHERE { { ?resource rdfs:label "Legend of Zelda: Majora's MaskThe Legend of Zelda: Majora's Mask"@en} UNION { ?resource rdfs:label "Legend of Zelda: Majora's MaskThe Legend of Zelda: Majora's Mask"@en}  UNION { ?resource rdfs:label "Legend of zelda: majora's maskthe legend of zelda: majora's mask"@en} }
# 26310680_0_5150772059999313798 1 193
# St Helena Pound
# SELECT ?resource WHERE { { ?resource rdfs:label "St Helena Pound"@en} UNION { ?resource rdfs:label "St Helena Pound"@en}  UNION { ?resource rdfs:label "St helena pound"@en} }
# 21245481_0_8730460088443117515 1 130
# Thunderbird, Lake
# SELECT ?resource WHERE { { ?resource rdfs:label "Thunderbird, Lake"@en} UNION { ?resource rdfs:label "Thunderbird, Lake"@en}  UNION { ?resource rdfs:label "Thunderbird, lake"@en}  UNION { ?resource rdfs:label "Thunderbird Lake"@en}  UNION { ?resource rdfs:label "Thunderbird, Lake"@de}  UNION { ?resource rdfs:label "Thunderbird, lake"@de}  UNION { ?resource rdfs:label "Thunderbird Lake"@de} }
# 91959037_0_7907661684242014480 1 347
# World Of Warcraft: Wrath Of The Lich King - Addon
# SELECT ?resource WHERE { { ?resource rdfs:label "World Of Warcraft: Wrath Of The Lich King - Addon"@en} UNION { ?resource rdfs:label "World Of Warcraft: Wrath Of The Lich King - Addon"@en}  UNION { ?resource rdfs:label "World of warcraft: wrath of the lich king - addon"@en}  UNION { ?resource rdfs:label "World Of Warcraft: Wrath Of The Lich King   Addon"@en} }
# 21245481_0_8730460088443117515 1 74
# Alum Creek Lake Also includes Delaware Lake, OH and Hoover Reservoir, OH
# SELECT ?resource WHERE { { ?resource rdfs:label "Alum Creek Lake Also includes Delaware Lake, OH and Hoover Reservoir, OH"@en} UNION { ?resource rdfs:label "Alum Creek Lake Also includes Delaware Lake, OH and Hoover Reservoir, OH"@en}  UNION { ?resource rdfs:label "Alum creek lake also includes delaware lake, oh and hoover reservoir, oh"@en}  UNION { ?resource rdfs:label "Alum Creek Lake Also includes Delaware Lake OH and Hoover Reservoir OH"@en} }
# 21245481_0_8730460088443117515 1 51
# D'Arbonne, Lake
# SELECT ?resource WHERE { { ?resource rdfs:label "D'Arbonne, Lake"@en} UNION { ?resource rdfs:label "D'Arbonne, Lake"@en}  UNION { ?resource rdfs:label "D'arbonne, lake"@en}  UNION { ?resource rdfs:label "D'Arbonne Lake"@en}  UNION { ?resource rdfs:label "D'Arbonne, Lake"@nl}  UNION { ?resource rdfs:label "D'arbonne, lake"@nl}  UNION { ?resource rdfs:label "D'Arbonne Lake"@nl} }
# 63450419_0_8012592961815711786 1 61
# Carex lenticularis var. dolia
# SELECT ?resource WHERE { { ?resource rdfs:label "Carex lenticularis var. dolia"@en} UNION { ?resource rdfs:label "Carex lenticularis var. dolia"@en}  UNION { ?resource rdfs:label "Carex lenticularis var. dolia"@en}  UNION { ?resource rdfs:label "Carex lenticularis var. dolia"@ca}  UNION { ?resource rdfs:label "Carex lenticularis var. dolia"@ca} }
# 50245608_0_871275842592178099 0 41
# Civil Action, A
# SELECT ?resource WHERE { { ?resource rdfs:label "Civil Action, A"@en} UNION { ?resource rdfs:label "Civil Action, A"@en}  UNION { ?resource rdfs:label "Civil action, a"@en}  UNION { ?resource rdfs:label "Civil Action A"@en} }
# 88523363_0_8180214313099580515 0 81
# Calamus spp.
# SELECT ?resource WHERE { { ?resource rdfs:label "Calamus spp."@en} UNION { ?resource rdfs:label "Calamus spp."@en}  UNION { ?resource rdfs:label "Calamus spp."@en}  UNION { ?resource rdfs:label "Calamus spp."@id}  UNION { ?resource rdfs:label "Calamus spp."@id} }
# 33401079_0_9127583903019856402 0 11
# Georg Friedrich H?ndel
# SELECT ?resource WHERE { { ?resource rdfs:label "Georg Friedrich H?ndel"@en} UNION { ?resource rdfs:label "Georg Friedrich H?ndel"@en}  UNION { ?resource rdfs:label "Georg friedrich h?ndel"@en}  UNION { ?resource rdfs:label "Georg Friedrich Hndel"@en}  UNION { ?resource rdfs:label "Georg Friedrich H?ndel"@de}  UNION { ?resource rdfs:label "Georg friedrich h?ndel"@de}  UNION { ?resource rdfs:label "Georg Friedrich Hndel"@de} }
# 54719588_0_8417197176086756912 3 185
# Pope Of Greenwich Village
# SELECT ?resource WHERE { { ?resource rdfs:label "Pope Of Greenwich Village"@en} UNION { ?resource rdfs:label "Pope Of Greenwich Village"@en}  UNION { ?resource rdfs:label "Pope of greenwich village"@en}  UNION { ?resource rdfs:label "Pope Of Greenwich Village"@nl}  UNION { ?resource rdfs:label "Pope of greenwich village"@nl} }
# 20135078_0_7570343137119682530 1 4
# Rash?mon
# SELECT ?resource WHERE { { ?resource rdfs:label "Rash?mon"@en} UNION { ?resource rdfs:label "Rash?mon"@en}  UNION { ?resource rdfs:label "Rash?mon"@en}  UNION { ?resource rdfs:label "Rashmon"@en}  UNION { ?resource rdfs:label "Rash?mon"@sq}  UNION { ?resource rdfs:label "Rash?mon"@sq}  UNION { ?resource rdfs:label "Rashmon"@sq} }
# 22864497_0_8632623712684511496 0 285
# SBK X
# SELECT ?resource WHERE { { ?resource rdfs:label "SBK X"@en} UNION { ?resource rdfs:label "SBK X"@en}  UNION { ?resource rdfs:label "Sbk x"@en}  UNION { ?resource rdfs:label "SBK X"@so}  UNION { ?resource rdfs:label "Sbk x"@so} }
# 8468806_0_4382447409703007384 1 13
# Ontariosee
# SELECT ?resource WHERE { { ?resource rdfs:label "Ontariosee"@en} UNION { ?resource rdfs:label "Ontariosee"@en}  UNION { ?resource rdfs:label "Ontariosee"@en}  UNION { ?resource rdfs:label "Ontariosee"@fi}  UNION { ?resource rdfs:label "Ontariosee"@fi} }
# 91959037_0_7907661684242014480 1 76
# Burnout 3 - Takedown
# SELECT ?resource WHERE { { ?resource rdfs:label "Burnout 3 - Takedown"@en} UNION { ?resource rdfs:label "Burnout 3 - Takedown"@en}  UNION { ?resource rdfs:label "Burnout 3 - takedown"@en}  UNION { ?resource rdfs:label "Burnout 3   Takedown"@en} }
# 11833461_1_3811022039809817402 0 21
# Gradius III (900 Wii Points)
# SELECT ?resource WHERE { { ?resource rdfs:label "Gradius III (900 Wii Points)"@en} UNION { ?resource rdfs:label "Gradius III (900 Wii Points)"@en}  UNION { ?resource rdfs:label "Gradius iii (900 wii points)"@en}  UNION { ?resource rdfs:label "Gradius III (900 Wii Points)"@pl}  UNION { ?resource rdfs:label "Gradius iii (900 wii points)"@pl} }
# 91959037_0_7907661684242014480 1 174
# James Bond 007 - Nightfire
# SELECT ?resource WHERE { { ?resource rdfs:label "James Bond 007 - Nightfire"@en} UNION { ?resource rdfs:label "James Bond 007 - Nightfire"@en}  UNION { ?resource rdfs:label "James bond 007 - nightfire"@en}  UNION { ?resource rdfs:label "James Bond 007   Nightfire"@en} }
# 91959037_0_7907661684242014480 1 291
# Tom Clancy's Rainbow Six 3: Ravenshield
# SELECT ?resource WHERE { { ?resource rdfs:label "Tom Clancy's Rainbow Six 3: Ravenshield"@en} UNION { ?resource rdfs:label "Tom Clancy's Rainbow Six 3: Ravenshield"@en}  UNION { ?resource rdfs:label "Tom clancy's rainbow six 3: ravenshield"@en} }
# 8468806_0_4382447409703007384 1 18
# Onegasee
# SELECT ?resource WHERE { { ?resource rdfs:label "Onegasee"@en} UNION { ?resource rdfs:label "Onegasee"@en}  UNION { ?resource rdfs:label "Onegasee"@en}  UNION { ?resource rdfs:label "Onegasee"@et}  UNION { ?resource rdfs:label "Onegasee"@et} }
# 21245481_0_8730460088443117515 1 188
# Red Bluff Reservoir *
# SELECT ?resource WHERE { { ?resource rdfs:label "Red Bluff Reservoir *"@en} UNION { ?resource rdfs:label "Red Bluff Reservoir *"@en}  UNION { ?resource rdfs:label "Red bluff reservoir *"@en} }
# 33401079_0_9127583903019856402 0 77
# J?rgen Habermas
# SELECT ?resource WHERE { { ?resource rdfs:label "J?rgen Habermas"@en} UNION { ?resource rdfs:label "J?rgen Habermas"@en}  UNION { ?resource rdfs:label "J?rgen habermas"@en}  UNION { ?resource rdfs:label "Jrgen Habermas"@en}  UNION { ?resource rdfs:label "J?rgen Habermas"@de}  UNION { ?resource rdfs:label "J?rgen habermas"@de}  UNION { ?resource rdfs:label "Jrgen Habermas"@de} }
# 21245481_0_8730460088443117515 1 72
# Wylie, Lake *
# SELECT ?resource WHERE { { ?resource rdfs:label "Wylie, Lake *"@en} UNION { ?resource rdfs:label "Wylie, Lake *"@en}  UNION { ?resource rdfs:label "Wylie, lake *"@en}  UNION { ?resource rdfs:label "Wylie Lake *"@en}  UNION { ?resource rdfs:label "Wylie, Lake *"@af}  UNION { ?resource rdfs:label "Wylie, lake *"@af}  UNION { ?resource rdfs:label "Wylie Lake *"@af} }
# 11833461_1_3811022039809817402 0 59
# Final Fantasy III (900 Wii Points)
# SELECT ?resource WHERE { { ?resource rdfs:label "Final Fantasy III (900 Wii Points)"@en} UNION { ?resource rdfs:label "Final Fantasy III (900 Wii Points)"@en}  UNION { ?resource rdfs:label "Final fantasy iii (900 wii points)"@en}  UNION { ?resource rdfs:label "Final Fantasy III (900 Wii Points)"@ro}  UNION { ?resource rdfs:label "Final fantasy iii (900 wii points)"@ro} }
# 43237185_1_3636357855502246981 0 18
# Gustav Peter Lejeune Dirichlet
# SELECT ?resource WHERE { { ?resource rdfs:label "Gustav Peter Lejeune Dirichlet"@en} UNION { ?resource rdfs:label "Gustav Peter Lejeune Dirichlet"@en}  UNION { ?resource rdfs:label "Gustav peter lejeune dirichlet"@en}  UNION { ?resource rdfs:label "Gustav Peter Lejeune Dirichlet"@fr}  UNION { ?resource rdfs:label "Gustav peter lejeune dirichlet"@fr} }
# 22864497_0_8632623712684511496 0 139
# FC Instincts Predator
# SELECT ?resource WHERE { { ?resource rdfs:label "FC Instincts Predator"@en} UNION { ?resource rdfs:label "FC Instincts Predator"@en}  UNION { ?resource rdfs:label "Fc instincts predator"@en} }
# 54719588_0_8417197176086756912 3 130
# Star Wars: Episode II - Attack Of The Clones
# SELECT ?resource WHERE { { ?resource rdfs:label "Star Wars: Episode II - Attack Of The Clones"@en} UNION { ?resource rdfs:label "Star Wars: Episode II - Attack Of The Clones"@en}  UNION { ?resource rdfs:label "Star wars: episode ii - attack of the clones"@en}  UNION { ?resource rdfs:label "Star Wars: Episode II   Attack Of The Clones"@en} }
# 46671561_0_6122315295162029872 0 166
# Tom Clancy?s Rainbow Six Vegas 2
# SELECT ?resource WHERE { { ?resource rdfs:label "Tom Clancy?s Rainbow Six Vegas 2"@en} UNION { ?resource rdfs:label "Tom Clancy?s Rainbow Six Vegas 2"@en}  UNION { ?resource rdfs:label "Tom clancy?s rainbow six vegas 2"@en}  UNION { ?resource rdfs:label "Tom Clancys Rainbow Six Vegas 2"@en} }
# 9834884_0_3871985887467090123 1 373
# Broelmuseum
# SELECT ?resource WHERE { { ?resource rdfs:label "Broelmuseum"@en} UNION { ?resource rdfs:label "Broelmuseum"@en}  UNION { ?resource rdfs:label "Broelmuseum"@en}  UNION { ?resource rdfs:label "Broelmuseum"@fi}  UNION { ?resource rdfs:label "Broelmuseum"@fi} }
# 9834884_0_3871985887467090123 1 98
# New Orleans Museum of Art (NOMA)
# SELECT ?resource WHERE { { ?resource rdfs:label "New Orleans Museum of Art (NOMA)"@en} UNION { ?resource rdfs:label "New Orleans Museum of Art (NOMA)"@en}  UNION { ?resource rdfs:label "New orleans museum of art (noma)"@en} }
# 21245481_0_8730460088443117515 1 148
# Belton Lake Also includes Stillhouse Hollow Lake, TX
# SELECT ?resource WHERE { { ?resource rdfs:label "Belton Lake Also includes Stillhouse Hollow Lake, TX"@en} UNION { ?resource rdfs:label "Belton Lake Also includes Stillhouse Hollow Lake, TX"@en}  UNION { ?resource rdfs:label "Belton lake also includes stillhouse hollow lake, tx"@en}  UNION { ?resource rdfs:label "Belton Lake Also includes Stillhouse Hollow Lake TX"@en} }
# 39107734_2_2329160387535788734 1 39
# Atat?rk International Airport
# SELECT ?resource WHERE { { ?resource rdfs:label "Atat?rk International Airport"@en} UNION { ?resource rdfs:label "Atat?rk International Airport"@en}  UNION { ?resource rdfs:label "Atat?rk international airport"@en}  UNION { ?resource rdfs:label "Atatrk International Airport"@en} }
# 36102169_0_7739454799295072814 2 3
# WWE Warzone
# SELECT ?resource WHERE { { ?resource rdfs:label "WWE Warzone"@en} UNION { ?resource rdfs:label "WWE Warzone"@en}  UNION { ?resource rdfs:label "Wwe warzone"@en}  UNION { ?resource rdfs:label "WWE Warzone"@pl}  UNION { ?resource rdfs:label "Wwe warzone"@pl} }
# 9834884_0_3871985887467090123 1 366
# Staatliche Graphische Sammlung M?nchen
# SELECT ?resource WHERE { { ?resource rdfs:label "Staatliche Graphische Sammlung M?nchen"@en} UNION { ?resource rdfs:label "Staatliche Graphische Sammlung M?nchen"@en}  UNION { ?resource rdfs:label "Staatliche graphische sammlung m?nchen"@en}  UNION { ?resource rdfs:label "Staatliche Graphische Sammlung Mnchen"@en}  UNION { ?resource rdfs:label "Staatliche Graphische Sammlung M?nchen"@de}  UNION { ?resource rdfs:label "Staatliche graphische sammlung m?nchen"@de}  UNION { ?resource rdfs:label "Staatliche Graphische Sammlung Mnchen"@de} }
# 8468806_0_4382447409703007384 1 100
# Chapalasee
# SELECT ?resource WHERE { { ?resource rdfs:label "Chapalasee"@en} UNION { ?resource rdfs:label "Chapalasee"@en}  UNION { ?resource rdfs:label "Chapalasee"@en}  UNION { ?resource rdfs:label "Chapalasee"@fi}  UNION { ?resource rdfs:label "Chapalasee"@fi} }
# 9834884_0_3871985887467090123 1 229
# Tatton Park, National Trust
# SELECT ?resource WHERE { { ?resource rdfs:label "Tatton Park, National Trust"@en} UNION { ?resource rdfs:label "Tatton Park, National Trust"@en}  UNION { ?resource rdfs:label "Tatton park, national trust"@en}  UNION { ?resource rdfs:label "Tatton Park National Trust"@en} }
# 10579449_0_1681126353774891032 1 11
# bbc Hindi
# SELECT ?resource WHERE { { ?resource rdfs:label "bbc Hindi"@en} UNION { ?resource rdfs:label "bbc Hindi"@en}  UNION { ?resource rdfs:label "Bbc hindi"@en} }
# 8468806_0_4382447409703007384 1 20
# Nicaraguasee
# SELECT ?resource WHERE { { ?resource rdfs:label "Nicaraguasee"@en} UNION { ?resource rdfs:label "Nicaraguasee"@en}  UNION { ?resource rdfs:label "Nicaraguasee"@en}  UNION { ?resource rdfs:label "Nicaraguasee"@es}  UNION { ?resource rdfs:label "Nicaraguasee"@es} }
# 9567241_0_5666388268510912770 1 21
# More Media >>
# SELECT ?resource WHERE { { ?resource rdfs:label "More Media >>"@en} UNION { ?resource rdfs:label "More Media >>"@en}  UNION { ?resource rdfs:label "More media >>"@en}  UNION { ?resource rdfs:label "More Media >>"@it}  UNION { ?resource rdfs:label "More media >>"@it} }
# 33401079_0_9127583903019856402 0 73
# Heinrich B?ll
# SELECT ?resource WHERE { { ?resource rdfs:label "Heinrich B?ll"@en} UNION { ?resource rdfs:label "Heinrich B?ll"@en}  UNION { ?resource rdfs:label "Heinrich b?ll"@en}  UNION { ?resource rdfs:label "Heinrich Bll"@en}  UNION { ?resource rdfs:label "Heinrich B?ll"@de}  UNION { ?resource rdfs:label "Heinrich b?ll"@de}  UNION { ?resource rdfs:label "Heinrich Bll"@de} }
# 34041816_1_4749054164534706977 1 14
# Istanbul Ataturk Airport[5]
# SELECT ?resource WHERE { { ?resource rdfs:label "Istanbul Ataturk Airport[5]"@en} UNION { ?resource rdfs:label "Istanbul Ataturk Airport[5]"@en}  UNION { ?resource rdfs:label "Istanbul ataturk airport[5]"@en}  UNION { ?resource rdfs:label "Istanbul Ataturk Airport5"@en} }
# 8468806_0_4382447409703007384 1 17
# Wostoksee
# SELECT ?resource WHERE { { ?resource rdfs:label "Wostoksee"@en} UNION { ?resource rdfs:label "Wostoksee"@en}  UNION { ?resource rdfs:label "Wostoksee"@en}  UNION { ?resource rdfs:label "Wostoksee"@fi}  UNION { ?resource rdfs:label "Wostoksee"@fi} }
# 8468806_0_4382447409703007384 1 82
# Lac-Minto
# SELECT ?resource WHERE { { ?resource rdfs:label "Lac-Minto"@en} UNION { ?resource rdfs:label "Lac-Minto"@en}  UNION { ?resource rdfs:label "Lac-minto"@en}  UNION { ?resource rdfs:label "Lac Minto"@en}  UNION { ?resource rdfs:label "Lac-Minto"@it}  UNION { ?resource rdfs:label "Lac-minto"@it}  UNION { ?resource rdfs:label "Lac Minto"@it} }
# 8468806_0_4382447409703007384 1 22
# Turkanasee
# SELECT ?resource WHERE { { ?resource rdfs:label "Turkanasee"@en} UNION { ?resource rdfs:label "Turkanasee"@en}  UNION { ?resource rdfs:label "Turkanasee"@en}  UNION { ?resource rdfs:label "Turkanasee"@fi}  UNION { ?resource rdfs:label "Turkanasee"@fi} }
# 66009064_0_9148652238372261251 0 229
# Bill McQuery
# SELECT ?resource WHERE { { ?resource rdfs:label "Bill McQuery"@en} UNION { ?resource rdfs:label "Bill McQuery"@en}  UNION { ?resource rdfs:label "Bill mcquery"@en}  UNION { ?resource rdfs:label "Bill McQuery"@fr}  UNION { ?resource rdfs:label "Bill mcquery"@fr} }
# 9834884_0_3871985887467090123 1 97
# Amsterdams Historisch Museum (AHM)
# SELECT ?resource WHERE { { ?resource rdfs:label "Amsterdams Historisch Museum (AHM)"@en} UNION { ?resource rdfs:label "Amsterdams Historisch Museum (AHM)"@en}  UNION { ?resource rdfs:label "Amsterdams historisch museum (ahm)"@en}  UNION { ?resource rdfs:label "Amsterdams Historisch Museum (AHM)"@de}  UNION { ?resource rdfs:label "Amsterdams historisch museum (ahm)"@de} }
# 91959037_0_7907661684242014480 1 233
# Pok?mon Feuerrote Edition
# SELECT ?resource WHERE { { ?resource rdfs:label "Pok?mon Feuerrote Edition"@en} UNION { ?resource rdfs:label "Pok?mon Feuerrote Edition"@en}  UNION { ?resource rdfs:label "Pok?mon feuerrote edition"@en}  UNION { ?resource rdfs:label "Pokmon Feuerrote Edition"@en} }
# 54719588_0_8417197176086756912 3 103
# Thin Line Between Love And Hate
# SELECT ?resource WHERE { { ?resource rdfs:label "Thin Line Between Love And Hate"@en} UNION { ?resource rdfs:label "Thin Line Between Love And Hate"@en}  UNION { ?resource rdfs:label "Thin line between love and hate"@en} }
# 91959037_0_7907661684242014480 1 360
# Prince of Persia - The Sands of Time
# SELECT ?resource WHERE { { ?resource rdfs:label "Prince of Persia - The Sands of Time"@en} UNION { ?resource rdfs:label "Prince of Persia - The Sands of Time"@en}  UNION { ?resource rdfs:label "Prince of persia - the sands of time"@en}  UNION { ?resource rdfs:label "Prince of Persia   The Sands of Time"@en} }
# 13719111_1_5719401842463579519 0 501
# Weyn's weaver
# SELECT ?resource WHERE { { ?resource rdfs:label "Weyn's weaver"@en} UNION { ?resource rdfs:label "Weyn's weaver"@en}  UNION { ?resource rdfs:label "Weyn's weaver"@en} }
# 14067031_0_559833072073397908 0 53
# Zambabwe
# SELECT ?resource WHERE { { ?resource rdfs:label "Zambabwe"@en} UNION { ?resource rdfs:label "Zambabwe"@en}  UNION { ?resource rdfs:label "Zambabwe"@en}  UNION { ?resource rdfs:label "Zambabwe"@sw}  UNION { ?resource rdfs:label "Zambabwe"@sw} }
# 8468806_0_4382447409703007384 1 10
# Gro?er-Sklavensee
# SELECT ?resource WHERE { { ?resource rdfs:label "Gro?er-Sklavensee"@en} UNION { ?resource rdfs:label "Gro?er-Sklavensee"@en}  UNION { ?resource rdfs:label "Gro?er-sklavensee"@en}  UNION { ?resource rdfs:label "Groer-Sklavensee"@en}  UNION { ?resource rdfs:label "Gro?er Sklavensee"@en}  UNION { ?resource rdfs:label "Gro?er-Sklavensee"@no}  UNION { ?resource rdfs:label "Gro?er-sklavensee"@no}  UNION { ?resource rdfs:label "Groer-Sklavensee"@no}  UNION { ?resource rdfs:label "Gro?er Sklavensee"@no} }
# 21245481_0_8730460088443117515 1 183
# O' the Pines, Lake (updated on 06/07/2004)
# SELECT ?resource WHERE { { ?resource rdfs:label "O' the Pines, Lake (updated on 06/07/2004)"@en} UNION { ?resource rdfs:label "O' the Pines, Lake (updated on 06/07/2004)"@en}  UNION { ?resource rdfs:label "O' the pines, lake (updated on 06/07/2004)"@en}  UNION { ?resource rdfs:label "O' the Pines Lake (updated on 06/07/2004)"@en} }
# 9834884_0_3871985887467090123 1 64
# Gem?ldegalerie, Staatliche Museen zu Berlin
# SELECT ?resource WHERE { { ?resource rdfs:label "Gem?ldegalerie, Staatliche Museen zu Berlin"@en} UNION { ?resource rdfs:label "Gem?ldegalerie, Staatliche Museen zu Berlin"@en}  UNION { ?resource rdfs:label "Gem?ldegalerie, staatliche museen zu berlin"@en}  UNION { ?resource rdfs:label "Gemldegalerie, Staatliche Museen zu Berlin"@en}  UNION { ?resource rdfs:label "Gem?ldegalerie Staatliche Museen zu Berlin"@en}  UNION { ?resource rdfs:label "Gem?ldegalerie, Staatliche Museen zu Berlin"@de}  UNION { ?resource rdfs:label "Gem?ldegalerie, staatliche museen zu berlin"@de}  UNION { ?resource rdfs:label "Gemldegalerie, Staatliche Museen zu Berlin"@de}  UNION { ?resource rdfs:label "Gem?ldegalerie Staatliche Museen zu Berlin"@de} }
# 9834884_0_3871985887467090123 1 3
# Mus?e du Louvre
# SELECT ?resource WHERE { { ?resource rdfs:label "Mus?e du Louvre"@en} UNION { ?resource rdfs:label "Mus?e du Louvre"@en}  UNION { ?resource rdfs:label "Mus?e du louvre"@en}  UNION { ?resource rdfs:label "Muse du Louvre"@en}  UNION { ?resource rdfs:label "Mus?e du Louvre"@fr}  UNION { ?resource rdfs:label "Mus?e du louvre"@fr}  UNION { ?resource rdfs:label "Muse du Louvre"@fr} }
# 9834884_0_3871985887467090123 1 137
# Koninklijk Instituut voor het Kunstpatrimonium (KIK)
# SELECT ?resource WHERE { { ?resource rdfs:label "Koninklijk Instituut voor het Kunstpatrimonium (KIK)"@en} UNION { ?resource rdfs:label "Koninklijk Instituut voor het Kunstpatrimonium (KIK)"@en}  UNION { ?resource rdfs:label "Koninklijk instituut voor het kunstpatrimonium (kik)"@en}  UNION { ?resource rdfs:label "Koninklijk Instituut voor het Kunstpatrimonium (KIK)"@et}  UNION { ?resource rdfs:label "Koninklijk instituut voor het kunstpatrimonium (kik)"@et} }
# 99070098_0_2074872741302696997 1 24
# Crag Hill (Eel Crag)
# SELECT ?resource WHERE { { ?resource rdfs:label "Crag Hill (Eel Crag)"@en} UNION { ?resource rdfs:label "Crag Hill (Eel Crag)"@en}  UNION { ?resource rdfs:label "Crag hill (eel crag)"@en}  UNION { ?resource rdfs:label "Crag Hill (Eel Crag)"@cy}  UNION { ?resource rdfs:label "Crag hill (eel crag)"@cy} }
# 63450419_0_8012592961815711786 1 71
# Cladium jamaicense
# SELECT ?resource WHERE { { ?resource rdfs:label "Cladium jamaicense"@en} UNION { ?resource rdfs:label "Cladium jamaicense"@en}  UNION { ?resource rdfs:label "Cladium jamaicense"@en}  UNION { ?resource rdfs:label "Cladium jamaicense"@pt}  UNION { ?resource rdfs:label "Cladium jamaicense"@pt} }
# 52299421_0_4473286348258170200 1 26
# Cyprus (2)
# SELECT ?resource WHERE { { ?resource rdfs:label "Cyprus (2)"@en} UNION { ?resource rdfs:label "Cyprus (2)"@en}  UNION { ?resource rdfs:label "Cyprus (2)"@en}  UNION { ?resource rdfs:label "Cyprus (2)"@lt}  UNION { ?resource rdfs:label "Cyprus (2)"@lt} }
# 21245481_0_8730460088443117515 1 24
# Pyramid Lake (updated 04/18/2005) Also includes Castaic Lake, CA
# SELECT ?resource WHERE { { ?resource rdfs:label "Pyramid Lake (updated 04/18/2005) Also includes Castaic Lake, CA"@en} UNION { ?resource rdfs:label "Pyramid Lake (updated 04/18/2005) Also includes Castaic Lake, CA"@en}  UNION { ?resource rdfs:label "Pyramid lake (updated 04/18/2005) also includes castaic lake, ca"@en}  UNION { ?resource rdfs:label "Pyramid Lake (updated 04/18/2005) Also includes Castaic Lake CA"@en} }
# 91959037_0_7907661684242014480 1 246
# Call Of Duty 5: World At War
# SELECT ?resource WHERE { { ?resource rdfs:label "Call Of Duty 5: World At War"@en} UNION { ?resource rdfs:label "Call Of Duty 5: World At War"@en}  UNION { ?resource rdfs:label "Call of duty 5: world at war"@en} }
# 21245481_0_8730460088443117515 1 43
# Big Hill Lake * (updated 01/23/2006)
# SELECT ?resource WHERE { { ?resource rdfs:label "Big Hill Lake * (updated 01/23/2006)"@en} UNION { ?resource rdfs:label "Big Hill Lake * (updated 01/23/2006)"@en}  UNION { ?resource rdfs:label "Big hill lake * (updated 01/23/2006)"@en} }
# 11833461_1_3811022039809817402 0 50
# Final Fantasy II (900 Wii Points)
# SELECT ?resource WHERE { { ?resource rdfs:label "Final Fantasy II (900 Wii Points)"@en} UNION { ?resource rdfs:label "Final Fantasy II (900 Wii Points)"@en}  UNION { ?resource rdfs:label "Final fantasy ii (900 wii points)"@en} }
# 22864497_0_8632623712684511496 0 229
# Need for Speed: Most Wanted (NFS Most Wanted)
# SELECT ?resource WHERE { { ?resource rdfs:label "Need for Speed: Most Wanted (NFS Most Wanted)"@en} UNION { ?resource rdfs:label "Need for Speed: Most Wanted (NFS Most Wanted)"@en}  UNION { ?resource rdfs:label "Need for speed: most wanted (nfs most wanted)"@en} }
# 60319454_0_3938426910282115527 0 17
# Fennec or desert fox
# SELECT ?resource WHERE { { ?resource rdfs:label "Fennec or desert fox"@en} UNION { ?resource rdfs:label "Fennec or desert fox"@en}  UNION { ?resource rdfs:label "Fennec or desert fox"@en}  UNION { ?resource rdfs:label "Fennec or desert fox"@no}  UNION { ?resource rdfs:label "Fennec or desert fox"@no} }
# 9834884_0_3871985887467090123 1 362
# Zilvermuseum Sterckshof Provincie Antwerpen
# SELECT ?resource WHERE { { ?resource rdfs:label "Zilvermuseum Sterckshof Provincie Antwerpen"@en} UNION { ?resource rdfs:label "Zilvermuseum Sterckshof Provincie Antwerpen"@en}  UNION { ?resource rdfs:label "Zilvermuseum sterckshof provincie antwerpen"@en} }
# 84575189_0_6365692015941409487 2 91
# doctor who magazine
# SELECT ?resource WHERE { { ?resource rdfs:label "doctor who magazine"@en} UNION { ?resource rdfs:label "doctor who magazine"@en}  UNION { ?resource rdfs:label "Doctor who magazine"@en} }
# 21245481_0_8730460088443117515 1 152
# Buffalo Creek Reservoir *
# SELECT ?resource WHERE { { ?resource rdfs:label "Buffalo Creek Reservoir *"@en} UNION { ?resource rdfs:label "Buffalo Creek Reservoir *"@en}  UNION { ?resource rdfs:label "Buffalo creek reservoir *"@en} }
# 36102169_0_7739454799295072814 2 211
# Super Mario Advance 4: Super Mario World
# SELECT ?resource WHERE { { ?resource rdfs:label "Super Mario Advance 4: Super Mario World"@en} UNION { ?resource rdfs:label "Super Mario Advance 4: Super Mario World"@en}  UNION { ?resource rdfs:label "Super mario advance 4: super mario world"@en} }
# 9834884_0_3871985887467090123 1 70
# Sz?pm?v?szeti M?zeum
# SELECT ?resource WHERE { { ?resource rdfs:label "Sz?pm?v?szeti M?zeum"@en} UNION { ?resource rdfs:label "Sz?pm?v?szeti M?zeum"@en}  UNION { ?resource rdfs:label "Sz?pm?v?szeti m?zeum"@en}  UNION { ?resource rdfs:label "Szpmvszeti Mzeum"@en}  UNION { ?resource rdfs:label "Sz?pm?v?szeti M?zeum"@hu}  UNION { ?resource rdfs:label "Sz?pm?v?szeti m?zeum"@hu}  UNION { ?resource rdfs:label "Szpmvszeti Mzeum"@hu} }
# 9834884_0_3871985887467090123 1 239
# Tiroler Landesmuseum Ferdinandeum
# SELECT ?resource WHERE { { ?resource rdfs:label "Tiroler Landesmuseum Ferdinandeum"@en} UNION { ?resource rdfs:label "Tiroler Landesmuseum Ferdinandeum"@en}  UNION { ?resource rdfs:label "Tiroler landesmuseum ferdinandeum"@en}  UNION { ?resource rdfs:label "Tiroler Landesmuseum Ferdinandeum"@de}  UNION { ?resource rdfs:label "Tiroler landesmuseum ferdinandeum"@de} }
# 21245481_0_8730460088443117515 1 75
# Atwood Lake Also includes Leesville Lake, OH
# SELECT ?resource WHERE { { ?resource rdfs:label "Atwood Lake Also includes Leesville Lake, OH"@en} UNION { ?resource rdfs:label "Atwood Lake Also includes Leesville Lake, OH"@en}  UNION { ?resource rdfs:label "Atwood lake also includes leesville lake, oh"@en}  UNION { ?resource rdfs:label "Atwood Lake Also includes Leesville Lake OH"@en} }
# 29414811_13_8724394428539174350 1 2
# Super Mario Galaxy 2[132]
# SELECT ?resource WHERE { { ?resource rdfs:label "Super Mario Galaxy 2[132]"@en} UNION { ?resource rdfs:label "Super Mario Galaxy 2[132]"@en}  UNION { ?resource rdfs:label "Super mario galaxy 2[132]"@en}  UNION { ?resource rdfs:label "Super Mario Galaxy 2132"@en}  UNION { ?resource rdfs:label "Super Mario Galaxy 2[132]"@es}  UNION { ?resource rdfs:label "Super mario galaxy 2[132]"@es}  UNION { ?resource rdfs:label "Super Mario Galaxy 2132"@es} }
# 8468806_0_4382447409703007384 1 44
# Kiwusee
# SELECT ?resource WHERE { { ?resource rdfs:label "Kiwusee"@en} UNION { ?resource rdfs:label "Kiwusee"@en}  UNION { ?resource rdfs:label "Kiwusee"@en}  UNION { ?resource rdfs:label "Kiwusee"@sw}  UNION { ?resource rdfs:label "Kiwusee"@sw} }
# 9834884_0_3871985887467090123 1 83
# Kr?ller-M?ller Museum
# SELECT ?resource WHERE { { ?resource rdfs:label "Kr?ller-M?ller Museum"@en} UNION { ?resource rdfs:label "Kr?ller-M?ller Museum"@en}  UNION { ?resource rdfs:label "Kr?ller-m?ller museum"@en}  UNION { ?resource rdfs:label "Krller-Mller Museum"@en}  UNION { ?resource rdfs:label "Kr?ller M?ller Museum"@en}  UNION { ?resource rdfs:label "Kr?ller-M?ller Museum"@de}  UNION { ?resource rdfs:label "Kr?ller-m?ller museum"@de}  UNION { ?resource rdfs:label "Krller-Mller Museum"@de}  UNION { ?resource rdfs:label "Kr?ller M?ller Museum"@de} }
# 22864497_0_8632623712684511496 0 98
# Dance Dance Revolution Universe 3 (DDR Universe 3)
# SELECT ?resource WHERE { { ?resource rdfs:label "Dance Dance Revolution Universe 3 (DDR Universe 3)"@en} UNION { ?resource rdfs:label "Dance Dance Revolution Universe 3 (DDR Universe 3)"@en}  UNION { ?resource rdfs:label "Dance dance revolution universe 3 (ddr universe 3)"@en}  UNION { ?resource rdfs:label "Dance Dance Revolution Universe 3 (DDR Universe 3)"@fr}  UNION { ?resource rdfs:label "Dance dance revolution universe 3 (ddr universe 3)"@fr} }
# 8468806_0_4382447409703007384 1 38
# Vansee
# SELECT ?resource WHERE { { ?resource rdfs:label "Vansee"@en} UNION { ?resource rdfs:label "Vansee"@en}  UNION { ?resource rdfs:label "Vansee"@en}  UNION { ?resource rdfs:label "Vansee"@nl}  UNION { ?resource rdfs:label "Vansee"@nl} }
# 9834884_0_3871985887467090123 1 12
# Museum of Fine Arts (MFA)
# SELECT ?resource WHERE { { ?resource rdfs:label "Museum of Fine Arts (MFA)"@en} UNION { ?resource rdfs:label "Museum of Fine Arts (MFA)"@en}  UNION { ?resource rdfs:label "Museum of fine arts (mfa)"@en} }
# 21245481_0_8730460088443117515 1 128
# Stanley Draper Lake
# SELECT ?resource WHERE { { ?resource rdfs:label "Stanley Draper Lake"@en} UNION { ?resource rdfs:label "Stanley Draper Lake"@en}  UNION { ?resource rdfs:label "Stanley draper lake"@en}  UNION { ?resource rdfs:label "Stanley Draper Lake"@no}  UNION { ?resource rdfs:label "Stanley draper lake"@no} }
# 21245481_0_8730460088443117515 1 190
# Sheldon Reservoir *
# SELECT ?resource WHERE { { ?resource rdfs:label "Sheldon Reservoir *"@en} UNION { ?resource rdfs:label "Sheldon Reservoir *"@en}  UNION { ?resource rdfs:label "Sheldon reservoir *"@en} }
# 22864497_0_8632623712684511496 0 198
# MegaMind: Ultimate Showdown
# SELECT ?resource WHERE { { ?resource rdfs:label "MegaMind: Ultimate Showdown"@en} UNION { ?resource rdfs:label "MegaMind: Ultimate Showdown"@en}  UNION { ?resource rdfs:label "Megamind: ultimate showdown"@en} }
# 9834884_0_3871985887467090123 1 290
# Mus?e Fesch
# SELECT ?resource WHERE { { ?resource rdfs:label "Mus?e Fesch"@en} UNION { ?resource rdfs:label "Mus?e Fesch"@en}  UNION { ?resource rdfs:label "Mus?e fesch"@en}  UNION { ?resource rdfs:label "Muse Fesch"@en}  UNION { ?resource rdfs:label "Mus?e Fesch"@de}  UNION { ?resource rdfs:label "Mus?e fesch"@de}  UNION { ?resource rdfs:label "Muse Fesch"@de} }
# 99070098_0_2074872741302696997 1 140
# Sergeant?s Crag
# SELECT ?resource WHERE { { ?resource rdfs:label "Sergeant?s Crag"@en} UNION { ?resource rdfs:label "Sergeant?s Crag"@en}  UNION { ?resource rdfs:label "Sergeant?s crag"@en}  UNION { ?resource rdfs:label "Sergeants Crag"@en} }
# 21245481_0_8730460088443117515 1 140
# Fort Loudoun Lake (updated 06/07/2004)
# SELECT ?resource WHERE { { ?resource rdfs:label "Fort Loudoun Lake (updated 06/07/2004)"@en} UNION { ?resource rdfs:label "Fort Loudoun Lake (updated 06/07/2004)"@en}  UNION { ?resource rdfs:label "Fort loudoun lake (updated 06/07/2004)"@en} }
# 9834884_0_3871985887467090123 1 214
# Mus?e des Beaux-Arts de Rennes
# SELECT ?resource WHERE { { ?resource rdfs:label "Mus?e des Beaux-Arts de Rennes"@en} UNION { ?resource rdfs:label "Mus?e des Beaux-Arts de Rennes"@en}  UNION { ?resource rdfs:label "Mus?e des beaux-arts de rennes"@en}  UNION { ?resource rdfs:label "Muse des Beaux-Arts de Rennes"@en}  UNION { ?resource rdfs:label "Mus?e des Beaux Arts de Rennes"@en}  UNION { ?resource rdfs:label "Mus?e des Beaux-Arts de Rennes"@fr}  UNION { ?resource rdfs:label "Mus?e des beaux-arts de rennes"@fr}  UNION { ?resource rdfs:label "Muse des Beaux-Arts de Rennes"@fr}  UNION { ?resource rdfs:label "Mus?e des Beaux Arts de Rennes"@fr} }
# 80588006_0_6965325215443683359 1 21
# More Media >>
# SELECT ?resource WHERE { { ?resource rdfs:label "More Media >>"@en} UNION { ?resource rdfs:label "More Media >>"@en}  UNION { ?resource rdfs:label "More media >>"@en}  UNION { ?resource rdfs:label "More Media >>"@it}  UNION { ?resource rdfs:label "More media >>"@it} }
# 9834884_0_3871985887467090123 1 282
# Muzeum Czartoryskich
# SELECT ?resource WHERE { { ?resource rdfs:label "Muzeum Czartoryskich"@en} UNION { ?resource rdfs:label "Muzeum Czartoryskich"@en}  UNION { ?resource rdfs:label "Muzeum czartoryskich"@en}  UNION { ?resource rdfs:label "Muzeum Czartoryskich"@pl}  UNION { ?resource rdfs:label "Muzeum czartoryskich"@pl} }
# 26310680_0_5150772059999313798 1 222
# Tajik Ruble (old)
# SELECT ?resource WHERE { { ?resource rdfs:label "Tajik Ruble (old)"@en} UNION { ?resource rdfs:label "Tajik Ruble (old)"@en}  UNION { ?resource rdfs:label "Tajik ruble (old)"@en}  UNION { ?resource rdfs:label "Tajik Ruble (old)"@et}  UNION { ?resource rdfs:label "Tajik ruble (old)"@et} }
# 36102169_0_7739454799295072814 2 65
# 007: Tomorrow Never Die
# SELECT ?resource WHERE { { ?resource rdfs:label "007: Tomorrow Never Die"@en} UNION { ?resource rdfs:label "007: Tomorrow Never Die"@en}  UNION { ?resource rdfs:label "007: tomorrow never die"@en} }
# 22864497_0_8632623712684511496 0 360
# Viva Pi?ata: Party Animals
# SELECT ?resource WHERE { { ?resource rdfs:label "Viva Pi?ata: Party Animals"@en} UNION { ?resource rdfs:label "Viva Pi?ata: Party Animals"@en}  UNION { ?resource rdfs:label "Viva pi?ata: party animals"@en}  UNION { ?resource rdfs:label "Viva Piata: Party Animals"@en}  UNION { ?resource rdfs:label "Viva Pi?ata: Party Animals"@lt}  UNION { ?resource rdfs:label "Viva pi?ata: party animals"@lt}  UNION { ?resource rdfs:label "Viva Piata: Party Animals"@lt} }
# 22864497_0_8632623712684511496 0 96
# Dance Dance Revolution Universe (DDR Universe)
# SELECT ?resource WHERE { { ?resource rdfs:label "Dance Dance Revolution Universe (DDR Universe)"@en} UNION { ?resource rdfs:label "Dance Dance Revolution Universe (DDR Universe)"@en}  UNION { ?resource rdfs:label "Dance dance revolution universe (ddr universe)"@en}  UNION { ?resource rdfs:label "Dance Dance Revolution Universe (DDR Universe)"@fr}  UNION { ?resource rdfs:label "Dance dance revolution universe (ddr universe)"@fr} }
# 9834884_0_3871985887467090123 1 184
# Mus?e Cond?
# SELECT ?resource WHERE { { ?resource rdfs:label "Mus?e Cond?"@en} UNION { ?resource rdfs:label "Mus?e Cond?"@en}  UNION { ?resource rdfs:label "Mus?e cond?"@en}  UNION { ?resource rdfs:label "Muse Cond"@en} }
# 13719111_1_5719401842463579519 0 459
# [Lagden's bush-shrike]
# SELECT ?resource WHERE { { ?resource rdfs:label "[Lagden's bush-shrike]"@en} UNION { ?resource rdfs:label "[Lagden's bush-shrike]"@en}  UNION { ?resource rdfs:label "[lagden's bush-shrike]"@en}  UNION { ?resource rdfs:label "Lagden's bush-shrike"@en}  UNION { ?resource rdfs:label "[Lagden's bush shrike]"@en}  UNION { ?resource rdfs:label "[Lagden's bush-shrike]"@sq}  UNION { ?resource rdfs:label "[lagden's bush-shrike]"@sq}  UNION { ?resource rdfs:label "Lagden's bush-shrike"@sq}  UNION { ?resource rdfs:label "[Lagden's bush shrike]"@sq} }
# 39650055_5_7135804139753401681 1 52
# L'Or?al
# SELECT ?resource WHERE { { ?resource rdfs:label "L'Or?al"@en} UNION { ?resource rdfs:label "L'Or?al"@en}  UNION { ?resource rdfs:label "L'or?al"@en}  UNION { ?resource rdfs:label "L'Oral"@en}  UNION { ?resource rdfs:label "L'Or?al"@ca}  UNION { ?resource rdfs:label "L'or?al"@ca}  UNION { ?resource rdfs:label "L'Oral"@ca} }
# 13719111_1_5719401842463579519 0 0
# Amarcord
# index 0 is out of bounds for axis 0 with size 0
# 32
# 9834884_0_3871985887467090123 1 165
# Museo L?zaro Galdiano
# SELECT ?resource WHERE { { ?resource rdfs:label "Museo L?zaro Galdiano"@en} UNION { ?resource rdfs:label "Museo L?zaro Galdiano"@en}  UNION { ?resource rdfs:label "Museo l?zaro galdiano"@en}  UNION { ?resource rdfs:label "Museo Lzaro Galdiano"@en}  UNION { ?resource rdfs:label "Museo L?zaro Galdiano"@it}  UNION { ?resource rdfs:label "Museo l?zaro galdiano"@it}  UNION { ?resource rdfs:label "Museo Lzaro Galdiano"@it} }
# 11833461_1_3811022039809817402 0 63
# Chrono Trigger (900 Wii Points)
# SELECT ?resource WHERE { { ?resource rdfs:label "Chrono Trigger (900 Wii Points)"@en} UNION { ?resource rdfs:label "Chrono Trigger (900 Wii Points)"@en}  UNION { ?resource rdfs:label "Chrono trigger (900 wii points)"@en} }
# 21245481_0_8730460088443117515 1 142
# Alan Henry Reservoir *
# SELECT ?resource WHERE { { ?resource rdfs:label "Alan Henry Reservoir *"@en} UNION { ?resource rdfs:label "Alan Henry Reservoir *"@en}  UNION { ?resource rdfs:label "Alan henry reservoir *"@en}  UNION { ?resource rdfs:label "Alan Henry Reservoir *"@nl}  UNION { ?resource rdfs:label "Alan henry reservoir *"@nl} }
# 91959037_0_7907661684242014480 1 356
# Spyro 2 - Gateway to Glimmer
# SELECT ?resource WHERE { { ?resource rdfs:label "Spyro 2 - Gateway to Glimmer"@en} UNION { ?resource rdfs:label "Spyro 2 - Gateway to Glimmer"@en}  UNION { ?resource rdfs:label "Spyro 2 - gateway to glimmer"@en}  UNION { ?resource rdfs:label "Spyro 2   Gateway to Glimmer"@en} }
# 43237185_1_3636357855502246981 0 8
# C. L. Ferdinand Lindemann
# SELECT ?resource WHERE { { ?resource rdfs:label "C. L. Ferdinand Lindemann"@en} UNION { ?resource rdfs:label "C. L. Ferdinand Lindemann"@en}  UNION { ?resource rdfs:label "C. l. ferdinand lindemann"@en}  UNION { ?resource rdfs:label "C. L. Ferdinand Lindemann"@da}  UNION { ?resource rdfs:label "C. l. ferdinand lindemann"@da} }
# 9834884_0_3871985887467090123 1 197
# Kenwood, The Iveagh Bequest
# SELECT ?resource WHERE { { ?resource rdfs:label "Kenwood, The Iveagh Bequest"@en} UNION { ?resource rdfs:label "Kenwood, The Iveagh Bequest"@en}  UNION { ?resource rdfs:label "Kenwood, the iveagh bequest"@en}  UNION { ?resource rdfs:label "Kenwood The Iveagh Bequest"@en} }
# 37856682_0_6818907050314633217 0 104
# Ireland (Northern Ireland and the Republic of Ireland)
# SELECT ?resource WHERE { { ?resource rdfs:label "Ireland (Northern Ireland and the Republic of Ireland)"@en} UNION { ?resource rdfs:label "Ireland (Northern Ireland and the Republic of Ireland)"@en}  UNION { ?resource rdfs:label "Ireland (northern ireland and the republic of ireland)"@en} }
# 91959037_0_7907661684242014480 1 132
# Buzz! Das gro?e Quiz
# SELECT ?resource WHERE { { ?resource rdfs:label "Buzz! Das gro?e Quiz"@en} UNION { ?resource rdfs:label "Buzz! Das gro?e Quiz"@en}  UNION { ?resource rdfs:label "Buzz! das gro?e quiz"@en}  UNION { ?resource rdfs:label "Buzz! Das groe Quiz"@en}  UNION { ?resource rdfs:label "Buzz! Das gro?e Quiz"@de}  UNION { ?resource rdfs:label "Buzz! das gro?e quiz"@de}  UNION { ?resource rdfs:label "Buzz! Das groe Quiz"@de} }
# 21245481_0_8730460088443117515 1 112
# Hefner, Lake
# SELECT ?resource WHERE { { ?resource rdfs:label "Hefner, Lake"@en} UNION { ?resource rdfs:label "Hefner, Lake"@en}  UNION { ?resource rdfs:label "Hefner, lake"@en}  UNION { ?resource rdfs:label "Hefner Lake"@en}  UNION { ?resource rdfs:label "Hefner, Lake"@no}  UNION { ?resource rdfs:label "Hefner, lake"@no}  UNION { ?resource rdfs:label "Hefner Lake"@no} }
# 91959037_0_7907661684242014480 1 226
# Pok?mon - Gelbe Edition
# SELECT ?resource WHERE { { ?resource rdfs:label "Pok?mon - Gelbe Edition"@en} UNION { ?resource rdfs:label "Pok?mon - Gelbe Edition"@en}  UNION { ?resource rdfs:label "Pok?mon - gelbe edition"@en}  UNION { ?resource rdfs:label "Pokmon - Gelbe Edition"@en}  UNION { ?resource rdfs:label "Pok?mon   Gelbe Edition"@en} }
# 91959037_0_7907661684242014480 1 317
# Pok?mon Snap
# SELECT ?resource WHERE { { ?resource rdfs:label "Pok?mon Snap"@en} UNION { ?resource rdfs:label "Pok?mon Snap"@en}  UNION { ?resource rdfs:label "Pok?mon snap"@en}  UNION { ?resource rdfs:label "Pokmon Snap"@en}  UNION { ?resource rdfs:label "Pok?mon Snap"@tl}  UNION { ?resource rdfs:label "Pok?mon snap"@tl}  UNION { ?resource rdfs:label "Pokmon Snap"@tl} }
# 91959037_0_7907661684242014480 1 44
# Tomb Raider II: Starring Lara Croft
# SELECT ?resource WHERE { { ?resource rdfs:label "Tomb Raider II: Starring Lara Croft"@en} UNION { ?resource rdfs:label "Tomb Raider II: Starring Lara Croft"@en}  UNION { ?resource rdfs:label "Tomb raider ii: starring lara croft"@en} }
# 36102169_0_7739454799295072814 2 61
# Hitman 2: Assassin
# SELECT ?resource WHERE { { ?resource rdfs:label "Hitman 2: Assassin"@en} UNION { ?resource rdfs:label "Hitman 2: Assassin"@en}  UNION { ?resource rdfs:label "Hitman 2: assassin"@en}  UNION { ?resource rdfs:label "Hitman 2: Assassin"@fi}  UNION { ?resource rdfs:label "Hitman 2: assassin"@fi} }
# 13719111_1_5719401842463579519 0 67
# Ayre's hawk-eagle
# SELECT ?resource WHERE { { ?resource rdfs:label "Ayre's hawk-eagle"@en} UNION { ?resource rdfs:label "Ayre's hawk-eagle"@en}  UNION { ?resource rdfs:label "Ayre's hawk-eagle"@en}  UNION { ?resource rdfs:label "Ayre's hawk eagle"@en}  UNION { ?resource rdfs:label "Ayre's hawk-eagle"@tl}  UNION { ?resource rdfs:label "Ayre's hawk-eagle"@tl}  UNION { ?resource rdfs:label "Ayre's hawk eagle"@tl} }
# 22864497_0_8632623712684511496 0 118
# DiRT 2DiRT 2
# SELECT ?resource WHERE { { ?resource rdfs:label "DiRT 2DiRT 2"@en} UNION { ?resource rdfs:label "DiRT 2DiRT 2"@en}  UNION { ?resource rdfs:label "Dirt 2dirt 2"@en}  UNION { ?resource rdfs:label "DiRT 2DiRT 2"@de}  UNION { ?resource rdfs:label "Dirt 2dirt 2"@de} }
# 22864497_0_8632623712684511496 0 102
# Darkness, TheThe Darkness
# SELECT ?resource WHERE { { ?resource rdfs:label "Darkness, TheThe Darkness"@en} UNION { ?resource rdfs:label "Darkness, TheThe Darkness"@en}  UNION { ?resource rdfs:label "Darkness, thethe darkness"@en}  UNION { ?resource rdfs:label "Darkness TheThe Darkness"@en} }
# 21245481_0_8730460088443117515 1 168
# Holbrook, Lake * Also includes Lake Fork Reservoir, TX and Lake Quitman, TX
# SELECT ?resource WHERE { { ?resource rdfs:label "Holbrook, Lake * Also includes Lake Fork Reservoir, TX and Lake Quitman, TX"@en} UNION { ?resource rdfs:label "Holbrook, Lake * Also includes Lake Fork Reservoir, TX and Lake Quitman, TX"@en}  UNION { ?resource rdfs:label "Holbrook, lake * also includes lake fork reservoir, tx and lake quitman, tx"@en}  UNION { ?resource rdfs:label "Holbrook Lake * Also includes Lake Fork Reservoir TX and Lake Quitman TX"@en} }
# 21245481_0_8730460088443117515 1 176
# McQueeney, Lake *
# SELECT ?resource WHERE { { ?resource rdfs:label "McQueeney, Lake *"@en} UNION { ?resource rdfs:label "McQueeney, Lake *"@en}  UNION { ?resource rdfs:label "Mcqueeney, lake *"@en}  UNION { ?resource rdfs:label "McQueeney Lake *"@en} }
# 11833461_1_3811022039809817402 0 31
# Super Mario RPG: Legend of the Seven Stars (900 Wii Points)
# SELECT ?resource WHERE { { ?resource rdfs:label "Super Mario RPG: Legend of the Seven Stars (900 Wii Points)"@en} UNION { ?resource rdfs:label "Super Mario RPG: Legend of the Seven Stars (900 Wii Points)"@en}  UNION { ?resource rdfs:label "Super mario rpg: legend of the seven stars (900 wii points)"@en} }
# 63450419_0_8012592961815711786 1 32
# Bromus carinatus var. carinatus
# SELECT ?resource WHERE { { ?resource rdfs:label "Bromus carinatus var. carinatus"@en} UNION { ?resource rdfs:label "Bromus carinatus var. carinatus"@en}  UNION { ?resource rdfs:label "Bromus carinatus var. carinatus"@en}  UNION { ?resource rdfs:label "Bromus carinatus var. carinatus"@ro}  UNION { ?resource rdfs:label "Bromus carinatus var. carinatus"@ro} }
# 99070098_0_2074872741302696997 1 32
# High Raise (Far E Fells)
# SELECT ?resource WHERE { { ?resource rdfs:label "High Raise (Far E Fells)"@en} UNION { ?resource rdfs:label "High Raise (Far E Fells)"@en}  UNION { ?resource rdfs:label "High raise (far e fells)"@en} }
# 91959037_0_7907661684242014480 1 155
# Jak and Daxter - The Precursor Legacy
# SELECT ?resource WHERE { { ?resource rdfs:label "Jak and Daxter - The Precursor Legacy"@en} UNION { ?resource rdfs:label "Jak and Daxter - The Precursor Legacy"@en}  UNION { ?resource rdfs:label "Jak and daxter - the precursor legacy"@en}  UNION { ?resource rdfs:label "Jak and Daxter   The Precursor Legacy"@en} }
# 9834884_0_3871985887467090123 1 221
# Museum het Rembrandthuis
# SELECT ?resource WHERE { { ?resource rdfs:label "Museum het Rembrandthuis"@en} UNION { ?resource rdfs:label "Museum het Rembrandthuis"@en}  UNION { ?resource rdfs:label "Museum het rembrandthuis"@en}  UNION { ?resource rdfs:label "Museum het Rembrandthuis"@nl}  UNION { ?resource rdfs:label "Museum het rembrandthuis"@nl} }
# 21245481_0_8730460088443117515 1 173
# Lost Creek Lake *
# SELECT ?resource WHERE { { ?resource rdfs:label "Lost Creek Lake *"@en} UNION { ?resource rdfs:label "Lost Creek Lake *"@en}  UNION { ?resource rdfs:label "Lost creek lake *"@en}  UNION { ?resource rdfs:label "Lost Creek Lake *"@nl}  UNION { ?resource rdfs:label "Lost creek lake *"@nl} }
# 8468806_0_4382447409703007384 1 8
# Gro?er-B?rensee
# SELECT ?resource WHERE { { ?resource rdfs:label "Gro?er-B?rensee"@en} UNION { ?resource rdfs:label "Gro?er-B?rensee"@en}  UNION { ?resource rdfs:label "Gro?er-b?rensee"@en}  UNION { ?resource rdfs:label "Groer-Brensee"@en}  UNION { ?resource rdfs:label "Gro?er B?rensee"@en}  UNION { ?resource rdfs:label "Gro?er-B?rensee"@nl}  UNION { ?resource rdfs:label "Gro?er-b?rensee"@nl}  UNION { ?resource rdfs:label "Groer-Brensee"@nl}  UNION { ?resource rdfs:label "Gro?er B?rensee"@nl} }
# 8468806_0_4382447409703007384 1 43
# Aydar-Ko?l
# SELECT ?resource WHERE { { ?resource rdfs:label "Aydar-Ko?l"@en} UNION { ?resource rdfs:label "Aydar-Ko?l"@en}  UNION { ?resource rdfs:label "Aydar-ko?l"@en}  UNION { ?resource rdfs:label "Aydar-Kol"@en}  UNION { ?resource rdfs:label "Aydar Ko?l"@en}  UNION { ?resource rdfs:label "Aydar-Ko?l"@tr}  UNION { ?resource rdfs:label "Aydar-ko?l"@tr}  UNION { ?resource rdfs:label "Aydar-Kol"@tr}  UNION { ?resource rdfs:label "Aydar Ko?l"@tr} }
# 8468806_0_4382447409703007384 1 63
# Hara-Usa-Nor
# SELECT ?resource WHERE { { ?resource rdfs:label "Hara-Usa-Nor"@en} UNION { ?resource rdfs:label "Hara-Usa-Nor"@en}  UNION { ?resource rdfs:label "Hara-usa-nor"@en}  UNION { ?resource rdfs:label "Hara Usa Nor"@en}  UNION { ?resource rdfs:label "Hara-Usa-Nor"@tl}  UNION { ?resource rdfs:label "Hara-usa-nor"@tl}  UNION { ?resource rdfs:label "Hara Usa Nor"@tl} }
# 36102169_0_7739454799295072814 2 72
# Nascar 99
# SELECT ?resource WHERE { { ?resource rdfs:label "Nascar 99"@en} UNION { ?resource rdfs:label "Nascar 99"@en}  UNION { ?resource rdfs:label "Nascar 99"@en}  UNION { ?resource rdfs:label "Nascar 99"@es}  UNION { ?resource rdfs:label "Nascar 99"@es} }
# 9834884_0_3871985887467090123 1 255
# Nordico - Museum der Stadt Linz
# SELECT ?resource WHERE { { ?resource rdfs:label "Nordico - Museum der Stadt Linz"@en} UNION { ?resource rdfs:label "Nordico - Museum der Stadt Linz"@en}  UNION { ?resource rdfs:label "Nordico - museum der stadt linz"@en}  UNION { ?resource rdfs:label "Nordico   Museum der Stadt Linz"@en}  UNION { ?resource rdfs:label "Nordico - Museum der Stadt Linz"@de}  UNION { ?resource rdfs:label "Nordico - museum der stadt linz"@de}  UNION { ?resource rdfs:label "Nordico   Museum der Stadt Linz"@de} }
# 21245481_0_8730460088443117515 1 77
# Belmont Lake
# SELECT ?resource WHERE { { ?resource rdfs:label "Belmont Lake"@en} UNION { ?resource rdfs:label "Belmont Lake"@en}  UNION { ?resource rdfs:label "Belmont lake"@en}  UNION { ?resource rdfs:label "Belmont Lake"@hu}  UNION { ?resource rdfs:label "Belmont lake"@hu} }
# 50245608_0_871275842592178099 0 76
# Few Good Men , A
# SELECT ?resource WHERE { { ?resource rdfs:label "Few Good Men , A"@en} UNION { ?resource rdfs:label "Few Good Men , A"@en}  UNION { ?resource rdfs:label "Few good men , a"@en}  UNION { ?resource rdfs:label "Few Good Men  A"@en} }
# 22864497_0_8632623712684511496 0 182
# Legend of Spyro: Dawn of the Dragon, TheThe Legend of Spyro: Dawn of the Dragon
# ...
# 21245481_0_8730460088443117515 1 119
# McGee Creek Reservoir (updated 06/08/2005) Also includes Atoka Reservoir, OK
# SELECT ?resource WHERE { { ?resource rdfs:label "McGee Creek Reservoir (updated 06/08/2005) Also includes Atoka Reservoir, OK"@en} UNION { ?resource rdfs:label "McGee Creek Reservoir (updated 06/08/2005) Also includes Atoka Reservoir, OK"@en}  UNION { ?resource rdfs:label "Mcgee creek reservoir (updated 06/08/2005) also includes atoka reservoir, ok"@en}  UNION { ?resource rdfs:label "McGee Creek Reservoir (updated 06/08/2005) Also includes Atoka Reservoir OK"@en} }
# 39759273_0_1427898308030295194 1 72
# E. T. The Extra-Terrestrial
# SELECT ?resource WHERE { { ?resource rdfs:label "E. T. The Extra-Terrestrial"@en} UNION { ?resource rdfs:label "E. T. The Extra-Terrestrial"@en}  UNION { ?resource rdfs:label "E. t. the extra-terrestrial"@en}  UNION { ?resource rdfs:label "E. T. The Extra Terrestrial"@en} }
# 11833461_1_3811022039809817402 0 58
# Natsume Championship Wrestling (900 Wii Points)
# SELECT ?resource WHERE { { ?resource rdfs:label "Natsume Championship Wrestling (900 Wii Points)"@en} UNION { ?resource rdfs:label "Natsume Championship Wrestling (900 Wii Points)"@en}  UNION { ?resource rdfs:label "Natsume championship wrestling (900 wii points)"@en} }
# 36102169_0_7739454799295072814 2 337
# WCW Vs NWO: World Tour
# SELECT ?resource WHERE { { ?resource rdfs:label "WCW Vs NWO: World Tour"@en} UNION { ?resource rdfs:label "WCW Vs NWO: World Tour"@en}  UNION { ?resource rdfs:label "Wcw vs nwo: world tour"@en}  UNION { ?resource rdfs:label "WCW Vs NWO: World Tour"@nl}  UNION { ?resource rdfs:label "Wcw vs nwo: world tour"@nl} }
# 9834884_0_3871985887467090123 1 103
# Museo Nacional de Bellas Artes de Cuba
# SELECT ?resource WHERE { { ?resource rdfs:label "Museo Nacional de Bellas Artes de Cuba"@en} UNION { ?resource rdfs:label "Museo Nacional de Bellas Artes de Cuba"@en}  UNION { ?resource rdfs:label "Museo nacional de bellas artes de cuba"@en}  UNION { ?resource rdfs:label "Museo Nacional de Bellas Artes de Cuba"@es}  UNION { ?resource rdfs:label "Museo nacional de bellas artes de cuba"@es} }
# 21245481_0_8730460088443117515 1 174
# Lyndon B Johnson, Lake *
# SELECT ?resource WHERE { { ?resource rdfs:label "Lyndon B Johnson, Lake *"@en} UNION { ?resource rdfs:label "Lyndon B Johnson, Lake *"@en}  UNION { ?resource rdfs:label "Lyndon b johnson, lake *"@en}  UNION { ?resource rdfs:label "Lyndon B Johnson Lake *"@en} }
# 91959037_0_7907661684242014480 1 398
# Die Sims 3
# SELECT ?resource WHERE { { ?resource rdfs:label "Die Sims 3"@en} UNION { ?resource rdfs:label "Die Sims 3"@en}  UNION { ?resource rdfs:label "Die sims 3"@en}  UNION { ?resource rdfs:label "Die Sims 3"@af}  UNION { ?resource rdfs:label "Die sims 3"@af} }
# 54719588_0_8417197176086756912 3 206
# Wind Will Carry Us
# SELECT ?resource WHERE { { ?resource rdfs:label "Wind Will Carry Us"@en} UNION { ?resource rdfs:label "Wind Will Carry Us"@en}  UNION { ?resource rdfs:label "Wind will carry us"@en} }
# 13719111_1_5719401842463579519 0 391
# Chin-spot batis
# SELECT ?resource WHERE { { ?resource rdfs:label "Chin-spot batis"@en} UNION { ?resource rdfs:label "Chin-spot batis"@en}  UNION { ?resource rdfs:label "Chin-spot batis"@en}  UNION { ?resource rdfs:label "Chin spot batis"@en} }
# 21245481_0_8730460088443117515 1 171
# Lake Fork Reservoir * (updated 05/02/2005) Also includes Lake Holbrook, TX and Lake Quitman, TX
# SELECT ?resource WHERE { { ?resource rdfs:label "Lake Fork Reservoir * (updated 05/02/2005) Also includes Lake Holbrook, TX and Lake Quitman, TX"@en} UNION { ?resource rdfs:label "Lake Fork Reservoir * (updated 05/02/2005) Also includes Lake Holbrook, TX and Lake Quitman, TX"@en}  UNION { ?resource rdfs:label "Lake fork reservoir * (updated 05/02/2005) also includes lake holbrook, tx and lake quitman, tx"@en}  UNION { ?resource rdfs:label "Lake Fork Reservoir * (updated 05/02/2005) Also includes Lake Holbrook TX and Lake Quitman TX"@en} }
# 50245608_0_871275842592178099 0 190
# Seinfeld - Season 2 - Disc 1
# SELECT ?resource WHERE { { ?resource rdfs:label "Seinfeld - Season 2 - Disc 1"@en} UNION { ?resource rdfs:label "Seinfeld - Season 2 - Disc 1"@en}  UNION { ?resource rdfs:label "Seinfeld - season 2 - disc 1"@en}  UNION { ?resource rdfs:label "Seinfeld   Season 2   Disc 1"@en}  UNION { ?resource rdfs:label "Seinfeld - Season 2 - Disc 1"@de}  UNION { ?resource rdfs:label "Seinfeld - season 2 - disc 1"@de}  UNION { ?resource rdfs:label "Seinfeld   Season 2   Disc 1"@de} }
# 45073662_0_3179937335063201739 1 14
# Alex Rodriguez (172)
# SELECT ?resource WHERE { { ?resource rdfs:label "Alex Rodriguez (172)"@en} UNION { ?resource rdfs:label "Alex Rodriguez (172)"@en}  UNION { ?resource rdfs:label "Alex rodriguez (172)"@en}  UNION { ?resource rdfs:label "Alex Rodriguez (172)"@es}  UNION { ?resource rdfs:label "Alex rodriguez (172)"@es} }
# 22864497_0_8632623712684511496 0 111
# DeathSmiles II X
# SELECT ?resource WHERE { { ?resource rdfs:label "DeathSmiles II X"@en} UNION { ?resource rdfs:label "DeathSmiles II X"@en}  UNION { ?resource rdfs:label "Deathsmiles ii x"@en}  UNION { ?resource rdfs:label "DeathSmiles II X"@et}  UNION { ?resource rdfs:label "Deathsmiles ii x"@et} }
# 21245481_0_8730460088443117515 1 208
# RD Bailey Lake
# SELECT ?resource WHERE { { ?resource rdfs:label "RD Bailey Lake"@en} UNION { ?resource rdfs:label "RD Bailey Lake"@en}  UNION { ?resource rdfs:label "Rd bailey lake"@en}  UNION { ?resource rdfs:label "RD Bailey Lake"@tr}  UNION { ?resource rdfs:label "Rd bailey lake"@tr} }
# 9834884_0_3871985887467090123 1 190
# Cobra Museum voor Moderne Kunst
# SELECT ?resource WHERE { { ?resource rdfs:label "Cobra Museum voor Moderne Kunst"@en} UNION { ?resource rdfs:label "Cobra Museum voor Moderne Kunst"@en}  UNION { ?resource rdfs:label "Cobra museum voor moderne kunst"@en}  UNION { ?resource rdfs:label "Cobra Museum voor Moderne Kunst"@da}  UNION { ?resource rdfs:label "Cobra museum voor moderne kunst"@da} }
# 9834884_0_3871985887467090123 1 71
# Landesmuseum Joanneum - Alte Galerie
# SELECT ?resource WHERE { { ?resource rdfs:label "Landesmuseum Joanneum - Alte Galerie"@en} UNION { ?resource rdfs:label "Landesmuseum Joanneum - Alte Galerie"@en}  UNION { ?resource rdfs:label "Landesmuseum joanneum - alte galerie"@en}  UNION { ?resource rdfs:label "Landesmuseum Joanneum   Alte Galerie"@en}  UNION { ?resource rdfs:label "Landesmuseum Joanneum - Alte Galerie"@de}  UNION { ?resource rdfs:label "Landesmuseum joanneum - alte galerie"@de}  UNION { ?resource rdfs:label "Landesmuseum Joanneum   Alte Galerie"@de} }
# 9834884_0_3871985887467090123 1 309
# Sammlung E.G. B?hrle
# SELECT ?resource WHERE { { ?resource rdfs:label "Sammlung E.G. B?hrle"@en} UNION { ?resource rdfs:label "Sammlung E.G. B?hrle"@en}  UNION { ?resource rdfs:label "Sammlung e.g. b?hrle"@en}  UNION { ?resource rdfs:label "Sammlung E.G. Bhrle"@en}  UNION { ?resource rdfs:label "Sammlung E.G. B?hrle"@de}  UNION { ?resource rdfs:label "Sammlung e.g. b?hrle"@de}  UNION { ?resource rdfs:label "Sammlung E.G. Bhrle"@de} }
# 36102169_0_7739454799295072814 2 23
# Spider-Man: The Movie 2
# SELECT ?resource WHERE { { ?resource rdfs:label "Spider-Man: The Movie 2"@en} UNION { ?resource rdfs:label "Spider-Man: The Movie 2"@en}  UNION { ?resource rdfs:label "Spider-man: the movie 2"@en}  UNION { ?resource rdfs:label "Spider Man: The Movie 2"@en} }
# 9834884_0_3871985887467090123 1 210
# Mus?e de Grenoble
# SELECT ?resource WHERE { { ?resource rdfs:label "Mus?e de Grenoble"@en} UNION { ?resource rdfs:label "Mus?e de Grenoble"@en}  UNION { ?resource rdfs:label "Mus?e de grenoble"@en}  UNION { ?resource rdfs:label "Muse de Grenoble"@en}  UNION { ?resource rdfs:label "Mus?e de Grenoble"@es}  UNION { ?resource rdfs:label "Mus?e de grenoble"@es}  UNION { ?resource rdfs:label "Muse de Grenoble"@es} }
# 13719111_1_5719401842463579519 0 450
# Mountain black boubou
# SELECT ?resource WHERE { { ?resource rdfs:label "Mountain black boubou"@en} UNION { ?resource rdfs:label "Mountain black boubou"@en}  UNION { ?resource rdfs:label "Mountain black boubou"@en} }
# 11833461_1_3811022039809817402 0 20
# Mario's Super Picross (900 Wii Points)
# SELECT ?resource WHERE { { ?resource rdfs:label "Mario's Super Picross (900 Wii Points)"@en} UNION { ?resource rdfs:label "Mario's Super Picross (900 Wii Points)"@en}  UNION { ?resource rdfs:label "Mario's super picross (900 wii points)"@en} }
# 11833461_1_3811022039809817402 0 32
# DoReMi Fantasy: Milon's DokiDoki Adventure (900 Wii Points)
# SELECT ?resource WHERE { { ?resource rdfs:label "DoReMi Fantasy: Milon's DokiDoki Adventure (900 Wii Points)"@en} UNION { ?resource rdfs:label "DoReMi Fantasy: Milon's DokiDoki Adventure (900 Wii Points)"@en}  UNION { ?resource rdfs:label "Doremi fantasy: milon's dokidoki adventure (900 wii points)"@en} }
# 9834884_0_3871985887467090123 1 325
# Kasteel Huis Bergh
# SELECT ?resource WHERE { { ?resource rdfs:label "Kasteel Huis Bergh"@en} UNION { ?resource rdfs:label "Kasteel Huis Bergh"@en}  UNION { ?resource rdfs:label "Kasteel huis bergh"@en}  UNION { ?resource rdfs:label "Kasteel Huis Bergh"@af}  UNION { ?resource rdfs:label "Kasteel huis bergh"@af} }
# 9834884_0_3871985887467090123 1 196
# Escher in het Paleis
# SELECT ?resource WHERE { { ?resource rdfs:label "Escher in het Paleis"@en} UNION { ?resource rdfs:label "Escher in het Paleis"@en}  UNION { ?resource rdfs:label "Escher in het paleis"@en}  UNION { ?resource rdfs:label "Escher in het Paleis"@de}  UNION { ?resource rdfs:label "Escher in het paleis"@de} }
# 36102169_0_7739454799295072814 2 349
# WWE Smackdown vs Raw
# SELECT ?resource WHERE { { ?resource rdfs:label "WWE Smackdown vs Raw"@en} UNION { ?resource rdfs:label "WWE Smackdown vs Raw"@en}  UNION { ?resource rdfs:label "Wwe smackdown vs raw"@en}  UNION { ?resource rdfs:label "WWE Smackdown vs Raw"@pl}  UNION { ?resource rdfs:label "Wwe smackdown vs raw"@pl} }
# 9834884_0_3871985887467090123 1 228
# Muzej za umjetnost i obrt
# SELECT ?resource WHERE { { ?resource rdfs:label "Muzej za umjetnost i obrt"@en} UNION { ?resource rdfs:label "Muzej za umjetnost i obrt"@en}  UNION { ?resource rdfs:label "Muzej za umjetnost i obrt"@en}  UNION { ?resource rdfs:label "Muzej za umjetnost i obrt"@hr}  UNION { ?resource rdfs:label "Muzej za umjetnost i obrt"@hr} }
# 8468806_0_4382447409703007384 1 48
# Poop?-See
# SELECT ?resource WHERE { { ?resource rdfs:label "Poop?-See"@en} UNION { ?resource rdfs:label "Poop?-See"@en}  UNION { ?resource rdfs:label "Poop?-see"@en}  UNION { ?resource rdfs:label "Poop-See"@en}  UNION { ?resource rdfs:label "Poop? See"@en}  UNION { ?resource rdfs:label "Poop?-See"@nl}  UNION { ?resource rdfs:label "Poop?-see"@nl}  UNION { ?resource rdfs:label "Poop-See"@nl}  UNION { ?resource rdfs:label "Poop? See"@nl} }
# 22864497_0_8632623712684511496 0 146
# First Templar, TheThe First Templar
# SELECT ?resource WHERE { { ?resource rdfs:label "First Templar, TheThe First Templar"@en} UNION { ?resource rdfs:label "First Templar, TheThe First Templar"@en}  UNION { ?resource rdfs:label "First templar, thethe first templar"@en}  UNION { ?resource rdfs:label "First Templar TheThe First Templar"@en} }
# 9834884_0_3871985887467090123 1 278
# Gem?ldegalerie der Akademie der bildenden K?nste
# SELECT ?resource WHERE { { ?resource rdfs:label "Gem?ldegalerie der Akademie der bildenden K?nste"@en} UNION { ?resource rdfs:label "Gem?ldegalerie der Akademie der bildenden K?nste"@en}  UNION { ?resource rdfs:label "Gem?ldegalerie der akademie der bildenden k?nste"@en}  UNION { ?resource rdfs:label "Gemldegalerie der Akademie der bildenden Knste"@en}  UNION { ?resource rdfs:label "Gem?ldegalerie der Akademie der bildenden K?nste"@de}  UNION { ?resource rdfs:label "Gem?ldegalerie der akademie der bildenden k?nste"@de}  UNION { ?resource rdfs:label "Gemldegalerie der Akademie der bildenden Knste"@de} }
# 63450419_0_8012592961815711786 1 185
# Sporobolus flexuous
# SELECT ?resource WHERE { { ?resource rdfs:label "Sporobolus flexuous"@en} UNION { ?resource rdfs:label "Sporobolus flexuous"@en}  UNION { ?resource rdfs:label "Sporobolus flexuous"@en}  UNION { ?resource rdfs:label "Sporobolus flexuous"@sk}  UNION { ?resource rdfs:label "Sporobolus flexuous"@sk} }
# 21245481_0_8730460088443117515 1 195
# Twin Buttes Reservoir Also includes Lake Nasworthy, TX
# SELECT ?resource WHERE { { ?resource rdfs:label "Twin Buttes Reservoir Also includes Lake Nasworthy, TX"@en} UNION { ?resource rdfs:label "Twin Buttes Reservoir Also includes Lake Nasworthy, TX"@en}  UNION { ?resource rdfs:label "Twin buttes reservoir also includes lake nasworthy, tx"@en}  UNION { ?resource rdfs:label "Twin Buttes Reservoir Also includes Lake Nasworthy TX"@en} }
# 99070098_0_2074872741302696997 1 177
# Baystones (Wansfell)
# SELECT ?resource WHERE { { ?resource rdfs:label "Baystones (Wansfell)"@en} UNION { ?resource rdfs:label "Baystones (Wansfell)"@en}  UNION { ?resource rdfs:label "Baystones (wansfell)"@en} }
# 45073662_0_3179937335063201739 1 26
# Manny Ram?rez
# SELECT ?resource WHERE { { ?resource rdfs:label "Manny Ram?rez"@en} UNION { ?resource rdfs:label "Manny Ram?rez"@en}  UNION { ?resource rdfs:label "Manny ram?rez"@en}  UNION { ?resource rdfs:label "Manny Ramrez"@en}  UNION { ?resource rdfs:label "Manny Ram?rez"@pl}  UNION { ?resource rdfs:label "Manny ram?rez"@pl}  UNION { ?resource rdfs:label "Manny Ramrez"@pl} }
# 21245481_0_8730460088443117515 1 206
# Beech Fork Lake Also includes East Lynn Lake, WV
# SELECT ?resource WHERE { { ?resource rdfs:label "Beech Fork Lake Also includes East Lynn Lake, WV"@en} UNION { ?resource rdfs:label "Beech Fork Lake Also includes East Lynn Lake, WV"@en}  UNION { ?resource rdfs:label "Beech fork lake also includes east lynn lake, wv"@en}  UNION { ?resource rdfs:label "Beech Fork Lake Also includes East Lynn Lake WV"@en} }
# 9834884_0_3871985887467090123 1 322
# National History Museum of Latvia
# SELECT ?resource WHERE { { ?resource rdfs:label "National History Museum of Latvia"@en} UNION { ?resource rdfs:label "National History Museum of Latvia"@en}  UNION { ?resource rdfs:label "National history museum of latvia"@en} }
# 8468806_0_4382447409703007384 1 19
# Titicacasee
# SELECT ?resource WHERE { { ?resource rdfs:label "Titicacasee"@en} UNION { ?resource rdfs:label "Titicacasee"@en}  UNION { ?resource rdfs:label "Titicacasee"@en} }
# 21245481_0_8730460088443117515 1 165
# Granbury, Lake *
# SELECT ?resource WHERE { { ?resource rdfs:label "Granbury, Lake *"@en} UNION { ?resource rdfs:label "Granbury, Lake *"@en}  UNION { ?resource rdfs:label "Granbury, lake *"@en}  UNION { ?resource rdfs:label "Granbury Lake *"@en} }
# 90196673_0_5458330029110291950 0 378
# WAPITI OR ELK
# SELECT ?resource WHERE { { ?resource rdfs:label "WAPITI OR ELK"@en} UNION { ?resource rdfs:label "WAPITI OR ELK"@en}  UNION { ?resource rdfs:label "Wapiti or elk"@en}  UNION { ?resource rdfs:label "WAPITI OR ELK"@no}  UNION { ?resource rdfs:label "Wapiti or elk"@no} }
# 26310680_0_5150772059999313798 1 253
# New Dinar
# SELECT ?resource WHERE { { ?resource rdfs:label "New Dinar"@en} UNION { ?resource rdfs:label "New Dinar"@en}  UNION { ?resource rdfs:label "New dinar"@en} }
# 13719111_1_5719401842463579519 0 420
# Yellow-white-eye
# SELECT ?resource WHERE { { ?resource rdfs:label "Yellow-white-eye"@en} UNION { ?resource rdfs:label "Yellow-white-eye"@en}  UNION { ?resource rdfs:label "Yellow-white-eye"@en}  UNION { ?resource rdfs:label "Yellow white eye"@en} }
# 58891288_0_1117541047012405958 1 51
# Rash?mon
# SELECT ?resource WHERE { { ?resource rdfs:label "Rash?mon"@en} UNION { ?resource rdfs:label "Rash?mon"@en}  UNION { ?resource rdfs:label "Rash?mon"@en}  UNION { ?resource rdfs:label "Rashmon"@en}  UNION { ?resource rdfs:label "Rash?mon"@sq}  UNION { ?resource rdfs:label "Rash?mon"@sq}  UNION { ?resource rdfs:label "Rashmon"@sq} }
# 2225.5409264564514
# 615

# %%
print(result_df.shape)
print(target.shape)
result_df[:10]
# Out:
# (8415, 4)
# (8417, 3)
#                           TableID  ColumnID  RowID  \
# 0   50245608_0_871275842592178099         0    154
# 1  39107734_2_2329160387535788734         1     32
# 2  22864497_0_8632623712684511496         0    227
# 3  66009064_0_9148652238372261251         0     15
# 4  21362676_0_6854186738074119688         1     75
# 5   50245608_0_871275842592178099         0    186
# 6  40534006_0_4617468856744635526         1      1
# 7  36102169_0_7739454799295072814         2    286
# 8  53822652_0_5767892317858575530         1    141
# 9  60319454_0_3938426910282115527         0     29
#
#                                                  URI
# 0           http://dbpedia.org/resource/Pearl_Harbor
# 1  http://dbpedia.org/resource/Minneapolis%E2%80%...
# 2  http://dbpedia.org/resource/Need_for_Speed%3A_...
# 3         http://dbpedia.org/resource/Alex_Rodriguez
# 4              http://dbpedia.org/resource/King_Kong
# 5     http://dbpedia.org/resource/The_School_of_Rock
# 6              http://dbpedia.org/resource/Lex_Luger
# 7             http://dbpedia.org/resource/Crash_Bash
# 8        http://dbpedia.org/resource/The_Hurt_Locker
# 9                   http://dbpedia.org/resource/Lion

# %%
# zapisanie submission
# przez evaluator codes można sprawdzić wyniki
result_df.to_csv("D:\Dokumenty\Zastosowanie Technologii Informatycznych\evaluator_codes\evaluator_codes\data\my_submission3.csv",
                 index=False,
                 sep=',',
                header=False)

# %% [markdown]
# ### NIEISTOTNE, TESTY ITP.

# %%
df = pd.read_csv("D:\\Dokumenty\\Zastosowanie Technologii Informatycznych\\data\\CEA_Round1\\13719111_1_5719401842463579519.csv",
                sep=',')
df[:3]

# %%
detect(df.iloc[0:1, 1:2].values[0][0])

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://dbpedia.org/sparql")
sparql.setQuery("""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    SELECT ?label
    WHERE { <http://dbpedia.org/resource/Norway> rdfs:label ?label }
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

print(results)
for result in results["results"]["bindings"]:
    print(result["label"]["value"])

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://dbpedia.org/sparql")
sparql.setQuery("""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX ont: <http://dbpedia.org/ontology/>
    SELECT ?a, ?c
    WHERE { 
            # ?a ont:location <http://dbpedia.org/resource/Delft> . 
            FILTER regex(?a, "Ikea", "i")
          }
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

print(results)
# print(result['a'])
# print(result['b'])
# print(result['c'])

# for result in results["results"]["bindings"]:
#     print(type(result))

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

sss = "dbr:Game_of_Thrones"
sparql = SPARQLWrapper("http://dbpedia.org/sparql")
sparql.setQuery('''
ASK {e}
    VALUES (?r) {e} ({source}) {w}
        {e} ?r ?p ?o {w}
        UNION
        {e} ?s ?r ?o {w}
        UNION
        {e} ?s ?p ?r {w}
    {w} 
'''.format(source=sss, e="{", w="}"))
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

print(results)

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

sss = "dbr:Game_of_Thrones"
sparql = SPARQLWrapper("http://dbpedia.org/sparql")
sparql.setQuery('''
ASK {
    VALUES (?r) { (dbr:Gra_o_tron) }
        { ?r ?p ?o }
        UNION
        { ?s ?r ?o }
        UNION
        { ?s ?p ?r }
    } 
''')
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

print(results)

# %%
SELECT ?r ?p ?o
WHERE {
 VALUES (?r) { (dbr:Cat) }
        { ?r ?p ?o }
        UNION
        { ?s ?r ?o }
        UNION
        { ?s ?p ?r }
}

select ?s
where {
        { ?s rdfs:label "Kot domowy"@pl }
        UNION
        { "Kot domowy"@pl rdfs:label ?s }
} 

SELECT ?r
WHERE {
        { ?r rdfs:label "Kaspisches Meer"@de }

}

# %%
sparql = SPARQLWrapper("http://dbpedia.org/sparql")
sparql.setQuery("""
    SELECT ?resource
    WHERE { ?resource rdfs:label "Kaspisches Meer"@de }
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
# print(results['results']['bindings'][1]['r']['value'])
# results = str(results['results']['bindings'])
print(str(results['results']['bindings']))
if str(results['results']['bindings']).find("http://dbpedia.org/resource/") == -1:
    print("nie ma")
else:
    print('jest')
# for result_dict in results_list:
#     uri = result_dict['resource']['value']
#     match = re.match("http://dbpedia.org/resource/*", uri)
#     if match:
#         print(uri)
#     else:
#         print("NIE")

# print(results['results']['bindings'])

# %%
import re
match = re.match("http://dbpedia.org/resource/*",'http://dbpedia.org/resource/Caspian_Sea', re.M|re.I)
if match:
    print(match.group())
